# %%
from faker import Faker
import pandas as pd

fake = Faker()
gen_num = 10000

csvDF = pd.read_csv("./employees.csv")

# %%
headers = csvDF.columns.to_list()
headers
# Out:
# ['First Name',
#  'Last Name',
#  'Email',
#  'Phone',
#  'Gender',
#  'Age',
#  'Job Title',
#  'Years Of Experience',
#  'Salary',
#  'Department']

# %%
departments = csvDF["Department"].drop_duplicates().to_list()
departments
# Out:
# ['Product', 'Human Resource']

# %%
job_titles = csvDF["Job Title"].drop_duplicates().to_list()
job_titles.remove("HR Manager")

job_titles
# Out:
# ['Project Manager',
#  'Machine Learning Engineer',
#  'Web Developer',
#  'Mobile Developer',
#  'DevOps Engineer',
#  'Designer',
#  'Tester']

# %%
import random

def makeData():
    fname = fake.first_name()
    lname = fake.last_name()
    email = fake.email()
    number = fake.phone_number()
    gender = random.choice(['male', 'female', 'other'])
    age = random.randint(18,66)
    job_title = ""
    years_of_work = random.randint(0, age-18)
    sal = random.randint(30000, 200000)
    department = random.choice(departments)
    if department == "Human Resource":
        job_title = "HR Manager"
    else:
        job_title = random.choice(job_titles)
        
    return [fname, lname, email, number, gender, age, job_title, 
            years_of_work, sal, department]

# %%
new_data = [makeData() for _ in range(gen_num)]
ndDF = pd.DataFrame(new_data)
ndDF.columns = headers
csvDF = pd.concat([csvDF, ndDF])
csvDF
# Out:
#      First Name  Last Name                              Email  \
# 0          Jose      Lopez     joselopez0944@slingacademy.com
# 1         Diane     Carter   dianecarter1228@slingacademy.com
# 2         Shawn     Foster   shawnfoster2695@slingacademy.com
# 3        Brenda     Fisher  brendafisher3185@slingacademy.com
# 4          Sean     Hunter    seanhunter4753@slingacademy.com
# ...         ...        ...                                ...
# 9995      Cathy  Henderson           hendersonamy@example.org
# 9996      Susan     Larsen                 todd27@example.com
# 9997     Javier     Larson           smithfelicia@example.org
# 9998   Jennifer  Dougherty               thomas33@example.org
# 9999      Sarah     Gentry              anthony65@example.net
#
#                      Phone  Gender  Age                  Job Title  \
# 0     +1-971-533-4552x1542    male   25            Project Manager
# 1             881.633.0107  female   26  Machine Learning Engineer
# ...

# %%
csvDF.to_csv("./faker-employees.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 csvDF.to_csv("")
#
# File ~/dev/school/sp24/de-proj-cs510/venv/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
